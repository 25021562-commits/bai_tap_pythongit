# %%
#W2A1
print('Hello World!')
# Out:
# Hello World!

# %%
#W2A2
name = input("Nhập tên của bạn: ")
print(f"Hello {name} !")
# Out:
# Hello minh !

# %%
#W2A3
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
print(f"Tổng của a và b là: {a + b}")
print(f"Hiệu của a và b là: {a - b}")
print(f"Tích của a và b là: {a * b}")
print(f"Thương của a và b là: {a / b}")
print(f"Phần nguyên của a chia b là: {a // b}")
print(f"Số dư của a chia b là: {a % b}")
print(f"Kết quả số thực của phép chia a cho b là: {a / b:.2f}")
# Out:
# Tổng của a và b là: 19
# Hiệu của a và b là: 1
# Tích của a và b là: 90
# Thương của a và b là: 1.1111111111111112
# Phần nguyên của a chia b là: 1
# Số dư của a chia b là: 1
# Kết quả số thực của phép chia a cho b là: 1.11

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(float, input("Nhập hệ số a1, b1, c1, a2, b2, a3: ").split())
print(f"Điểm trung bình môn: {((a1 + b1 + c1) + (a2 +b2)*2 + a3*3) / 10:.1f}")
# Out:
# Điểm trung bình môn: 9.3

# %%
#W2A5
a, b = map(int, input("Nhập a, b : ").split())
print(f"a mũ b = {a**b}")
# Out:
# a mũ b = 1000

# %%
#W2A6
kytuthuong = input("Nhập một ký tự thường: ")
if len(kytuthuong) != 1:
    print("Vui lòng nhập đúng một ký tự.")
elif: 97 <= ord(kytuthuong) <= 122:
    maunicode = ord(kytuthuong)
    print(f"Mã Unicode của ký tự {kytuthuong} là: {maunicode}")
    kytuhoa = kytuthuong.upper()
    print(f"Ký tự hoa của {kytuthuong} là: {kytuhoa}")
else:
    print("không phải một ký tự thường")
# Out:
# Mã Unicode của ký tự m là: 109
# Ký tự hoa của m là: M

# %%
#W2A7
print(f"A= (13**2)*3 +5 = { (13**2)*3 +5 }")
print(f"B= 13**2*3 + 5 = { 13**2*3 + 5 }")
# Out:
# A= (13**2)*3 +5 = 512
# B= 13**2*3 + 5 = 512

# %%
#W2A8
C = float(input("Nhập nhiệt độ C: "))
F = (9/5) * C + 32
print(f"Nhiệt độ F tương ứng là: {F:.2f}")
# Out:
# Nhiệt độ F tương ứng là: 96.80

# %%
#W2A9
x = int(input("Giá của chiếc đồng hồ là: "))
print(f"Tổng số tiền phải trả là: {(x*(30/100 + 10/100) + 10):.2f} USD")
# Out:
# Tổng số tiền phải trả là: 1449.60 USD

# %%
#W2A10
name1, name2, name3 = input("Nhập tên 3 người bạn: ").split()
print(f"Chào {name3}, {name2} và {name1}.")
# Out:
# Chào nhi, linh và minh.

# %%
#W2A11
h, m = map(int, input("Nhập giờ và phút: ").split())
print(f"Đó là: {h*3600 + m*60} giây")
# Out:
# Đó là: 20340 giây

# %%
#W2A12
n = int(input("Nhập độ dài cạnh của rubik: "))
print(f"Số miếng dán riêng lẻ cần cho khối rubik có độ dài cạnh là {n} là: {6 * n**2}")
# Out:
# Số miếng dán riêng lẻ cần cho khối rubik có độ dài cạnh là 3 là: 54

# %%
# W2A13
a, b = map(int, input("Nhập a và b: ").split())
print(f"Chữ số hàng đơn vị của tích a và b là: {a*b % 10}")
# Out:
# Chữ số hàng đơn vị của tích a và b là: 7

# %%
# W2A14
a, b = map(int, input("Nhập số a: ").split())
a, b = b, a
print(f"Sau khi hoán đổi, a = {a}, b = {b}")
# Out:
# Sau khi hoán đổi, a = 6, b = 5

# %%
# W2A15
n = int(input("Nhập số nguyên dương n: "))
print(f"Số sao lớp thứ n là: {6 * (n - 1)}")
# Out:
# Số sao lớp thứ n là: 12

# %%
# W2A16
print("Spring\nSummer\nAutumn\nWinter")

for line in ["Spring", "Summer", "Autumn", "Winter"]:
    print(line)

import textwrap
text = "Spring Summer Autumn Winter"
print(textwrap.fill(text, width=6))

lines = ["Spring", "Summer", "Autumn", "Winter"]
print("\n".join(lines))
# Out:
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter

# %%
# W2A17
print("  *")
print(" ***")
print("*****")

lines = ["  *", " ***", "*****"]
print("\n".join(lines))
# Out:
#   *
#  ***
# *****
#   *
#  ***
# *****

# %%
# W2A18
print("### ##    ### ###")
print(" #  #  #   #  #")
print(" #  #   #  #  #")
print(" #  #  #   #  #")
print(" #  ##     #  #")
# Out:
# ### ##    ### ###
#  #  #  #   #  #
#  #  #   #  #  #
#  #  #  #   #  #
#  #  ##     #  #

# %%
# W2A19
lines = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
print("\n".join(lines))
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
lines = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
print("\n".join(lines))
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
# W2A21
for i in range(10):
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
