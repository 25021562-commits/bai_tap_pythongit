# %%
#bài 1
n = int(input('nhập số nguyên n: '))
print(f'Số gấp đôi của n là: {n*2}')
# Out:
# Số gấp đôi của n là: 10

# %%
#bài 2
a, b = map(int, input('Nhập chiều rộng và chiều dài a, b: ').split())
print(f'Diện tích phần trồng cây là: {(a*b- ((a/2)**2)*3.14):.2f}')

# %%
#bài 3
word = input('Nhập một từ trên bàn phím: ')
if word .isupper():
    print(f'Dạng chữ thường của {word} là:', word.lower())
elif word .islower():
    print(f'Dạng chữ hoa của {word} là:', word.upper())

# %%
#bài 4
word = input('Nhập một ký tự trên bàn phím: ')
if word .isalpha():
    print(f'Ký tự {word} là ký tự alphabet')
else:
    print(f'Ký tự {word} không phải là ký tự alphabet')
# Out:
# Ký tự m là ký tự alphabet

# %%
#bài 5
c = input("Nhập một chữ cái hoa: ")

if c == 'A':
    print("Không có chữ cái thường đứng trước 'a'. Đây là trường hợp đặc biệt.")
elif c.isupper() and 'B' <= c <= 'Z':
    truoc = chr(ord(c.lower()) - 1)
    print(f"Chữ cái thường liền trước của {c} là:", truoc)
else:
    print("Bạn phải nhập một chữ cái hoa từ A đến Z.")
# Out:
# Chữ cái thường liền trước của Y là: x

# %%
#bài 6
a, b, c = map(float, input("Nhập ba số a, b, c: ").split())
if a + b > c and a + c > b and b + c > a:
    d = (a + b + c) / 2
    S = (d * (d - a) * (d - b) * (d - c)) ** 0.5
    print(f'Diện tích tam giác là: {S:.1f}')
# Out:
# Diện tích tam giác là: 16.1

# %%
#bài 7
s = input("Nhập chuỗi ký tự thường có độ dài >=20: ")
if len(s) >=20:
    print("Chữ cái thứ năm trong chuỗi là:", s[4])
    print("Chữ cái thứ chin trong chuỗi là:", s[8])
else:
    print("Hãy nhập đủ chuỗi có độ dài >=20")
# Out:
# Chữ cái thứ năm trong chuỗi là: g
# Chữ cái thứ chin trong chuỗi là: y

# %%
#bài 8
def tinh_tien_dien(so_kwh):
    bac_gia = [
        (50, 1984),
        (50, 2050),
        (100, 2380),
        (100, 2998),
        (100, 3350),
        (float('inf'), 3460)
    ]

    tong_tien = 0
    kwh_con_lai = so_kwh

    for dinh_muc, gia in bac_gia:
        if kwh_con_lai > 0:
            kwh_tinh = min(kwh_con_lai, dinh_muc)
            tong_tien += kwh_tinh * gia
            kwh_con_lai -= kwh_tinh
        else:
            break

    return tong_tien

ten_chu_ho = input("Nhập tên chủ hộ: ")
chi_so_truoc = int(input("Nhập chỉ số tháng trước: "))
chi_so_sau = int(input("Nhập chỉ số tháng này: "))

# Tính số điện tiêu thụ
so_kwh = chi_so_sau - chi_so_truoc

# Tính tiền điện và VAT
tien_goc = tinh_tien_dien(so_kwh)
vat = tien_goc * 0.08
tong_tien = round(tien_goc + vat)

# In kết quả
print("\nHọ và tên:", ten_chu_ho)
print("Tiền phải trả là:", tong_tien, "VNĐ")
# Out:
# Họ và tên: seggggg
# Tiền phải trả là: 1855505 VNĐ

# %%
#1
n = int(input('nhập số nguyên n: '))
if n % 2 == 0:
    print(f'Số {n} là số chẵn')
else:
    print(f'Số {n} là số lẻ')
# Out:
# Số 9 là số lẻ

# %%
#2
n = int(input('nhập số nguyên n: '))
if n % 10 == 5:
    print('True')
else:
    print('False')
# Out:
# Số 8 không có chữ số tận cùng là 5

# %%
#3
n = int(input('nhập số nguyên n: '))
if n % 3 ==0 and n % 5 ==0:
    print('True')
else:
    print('False')
# Out:
# True

# %%
#4
age = int(input('nhập năm sinh của bạn:'))
if 2025-age >=18:
    print('bạn đủ tuổi bầu cử') 
else:
    print('bạn chưa đủ tuổi bầu cử')
# Out:
# bạn chưa đủ tuổi bầu cử

# %%
#5
a, b = map(int, input('nhập hai số a và b:').split())
if a>b:
    print(f'số {a} lớn hơn số {b}')
elif a<b:
    print(f'số {b} lớn hơn số {a}')
else:
    print('hai số bằng nhau')
# Out:
# số 8 lớn hơn số 5

# %%
#6
char = input('nhập giá trị trên bàn phím:')
if len(char) != 1:
    print("Vui lòng chỉ nhập một ký tự duy nhất.")
else:
    if char.isalpha():
        print("Ký tự bạn nhập là chữ cái.")
    elif char.isdigit():
        print("Ký tự bạn nhập là chữ số.")
    else:
        print("Ký tự bạn nhập không phải là chữ cái hay số.")
# Out:
# Ký tự bạn nhập là chữ cái.

# %%
#7
score = float(input("Nhập điểm số của sinh viên (0-10): "))
if 8 <= score <= 10:
    print("Xếp loại: Giỏi")
elif 6.5 <= score < 8:
    print("Xếp loại: Khá")
elif 5 <= score < 6.5:
    print("Xếp loại: Trung bình")
elif 0 <= score < 5:
    print("Xếp loại: Yếu")
# Out:
# Xếp loại: Giỏi

# %%
#8
year = int(input("Nhập năm cần kiểm tra: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"Năm {year} là năm nhuận.")
else:
    print(f"Năm {year} không phải là năm nhuận.")
# Out:
# Năm 2008 là năm nhuận.

# %%
#9
num = int(input("Nhập một số nguyên từ 0 đến 9: "))
match num:
    case 0:
        print("Không")
    case 1:
        print("Một")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bốn")
    case 5:
        print("Năm")
    case 6:
        print("Sáu")
    case 7:
        print("Bảy")
    case 8:
        print("Tám")
    case 9:
        print("Chín")
    case _:
        print("Số không hợp lệ! Vui lòng nhập từ 0 đến 9.")
# Out:
# Tám

# %%
#10
n = int(input("Nhập điểm thi: "))
if n >=4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Qua môn

# %%
#11
year = int(input("Nhập năm sinh của bạn: "))
if 2025 - year >= 18:
    print("Bạn đủ 18 tuổi")
else:
    print("Bạn chưa đủ 18 tuổi")
# Out:
# Bạn đủ 18 tuổi
