# %%
#W3A2
a = int(input('nhập a:'))
b = int(input('nhập b:'))         
       #^ là toán tử XOR
print("Trước khi hoán đổi: a =", a, ", b =", b)    #1001
a = a ^ b                                          #1011
b = a ^ b                                       #-->0010   #-->1011 ^ 0010 = 1001
a = a ^ b  
print("Sau khi hoán đổi: a =", a, ", b =", b)
# Out:
# Trước khi hoán đổi: a = 5 , b = 8
# Sau khi hoán đổi: a = 8 , b = 5

# %%
#W3A3
n = int(input("Nhập số cần kiểm tra: "))
if n > 0 and (n & (n - 1)) == 0:  #đưa n, n-1 về nhị phân và AND là xét bit nào cả 2 đều là 1
    print(n, "là lũy thừa của 2")
else:
    print(n, "không phải là lũy thừa của 2")
# Out:
# 14 không phải là lũy thừa của 2

# %%
#W3A4
m = int(input("Nhập số m: "))
n = int(input("Nhập số n: "))
ket_qua = m // n
print("Kết quả làm tròn xuống:", ket_qua)
# Out:
# Kết quả làm tròn xuống: 72

# %%
#W3A5
# import math
# m = int(input("Nhập số m: "))
# n = int(input("Nhập số n: "))
# ket_qua = math.ceil(m / n)
# print("Kết quả làm tròn lên:", ket_qua)

#c2
m = int(input("Nhập số m: "))
n = int(input("Nhập số n: "))
ket_qua = m // n
if m % n != 0: 
    ket_qua += 1
print(f"Kết quả làm tròn lên của phép {m}/{n}:", ket_qua)
# Out:
# Kết quả làm tròn lên của phép 993/12: 83

# %%
#W3A6
x = int(input("Nhập số nguyên dương x: "))

if x % 2 == 0:
    print("Even")   
else:
    print("Odd")
# Out:
# Even

# %%
#W3A7

a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A8
# a = input("Nhập chuỗi a: ")
# b = input("Nhập chuỗi b: ")

# # So sánh độ dài
# if len(a) > len(b):
#     print("True")
# else:
#     print("False")


a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")
count_a = 0
for i in a:
    count_a += 1
count_b = 0
for i in b:
    count_b += 1
if count_a > count_b:
    print("True")
else:
    print("False")
# Out:
# False

# %%
#W3A9
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
c = int(input("Nhập số c: "))
if a < b + c and b < a + c and c < a + b:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3A10
# a, b, c, d = map(int, input("Nhập 4 số nguyên a, b, c, d cách nhau bởi dấu cách: ").split())
# s = min(a, b, c, d)
# print("Số nhỏ nhất là:", s)

#C2
numbers = [int(x) for x in input("Nhập các số nguyên, cách nhau bởi khoảng trắng: ").split()]
min_num = numbers[0]        #giả sử số đầu tiên là nhỏ nhất
for num in numbers:
    if num < min_num:
        min_num = num
print("Số nhỏ nhất trong danh sách là:", min_num)
# Out:
# Số nhỏ nhất là: 1
# Số nhỏ nhất trong danh sách là: 3

# %%
#W3A11
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
c = int(input("Nhập số c: "))
if a < b+c and b < a+c and c < a+b:
    if a == b == c:
     print("Tam giác đều")
    elif a == b or b == c or c == a:
     print("Tam giác cân")
    else:
     print("Tam giác thường") 
else:
    print("Không phải tam giác")
# Out:
# Tam giác thường

# %%
#W3A12
n = int(input("Nhập năm: "))
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print(f"Yes {n} là năm nhuận")
# Out:
# Yes 2000 là năm nhuận

# %%
#W3A14
a = int(input("Nhập hệ số a của pt ax+b=0 : "))
b = int(input("Nhập hệ số b của pt ax+b=0 : "))
if a == 0:
    if b == 0:
        print("Phương trình có vô số nghiệm")
    else:
        print("Phương trình vô nghiệm")
if a != 0 and b != 0:
    x = -b / a
    print(f"Nghiệm của phương trình là x = {x:.2f}")
# Out:
# Nghiệm của phương trình là x = 1.50

# %%
#W3A15
# list_1 = [float(x) for x in input("Nhập điểm, cách nhau bởi dấu cách: ").split()]
# avg = sum(list_1) / len(list_1)
# if avg >=  8:
#     print("Giỏi")
# elif avg >= 6.5:
#     print("Khá")
# elif avg >= 5:
#     print("Trung bình")


#numbers = list(map(float, input("Nhập các số cách nhau bởi dấu cách: ").split()))
numbers = [float(x) for x in input("Nhập các số cách nhau bởi dấu cách: ").split()]
total = 0
count = 0
for x in numbers:
    total += x
    count += 1
if count > 0:
    average = total / count
    print(f"Trung bình của các giá trị là: {average:.2f}")
else:
    print("Danh sách rỗng, không tính được trung bình")
# Out:
# Trung bình của các giá trị là:, 8.58

# %%
#W3A16
n = float(input("Nhập số nguyên dương n: "))
print(n)
if n > 0:
    n1 = n +1
    print("Số làm tròn lên là:", int(n1))
    print("Số làm tròn xuống là:", int(n))
    n2 = n - int(n)
    if n2 >= 0.5:
        print("Số làm tròn gần nhất là:", int(n1))
    else:
        print("Số làm tròn gần nhất là:", int(n))
else:
    n1 = n - 1
    print("Số làm tròn lên là:", int(n))
    print("Số làm tròn xuống là:", int(n1))
    n2 = n - int(n)
    if n2 <= -0.5:
        print("Số làm tròn gần nhất là:", int(n1))
    else:
        print("Số làm tròn gần nhất là:", int(n))
# Out:
# -3.2
# Số làm tròn lên là: -3
# Số làm tròn xuống là: -4
# Số làm tròn gần nhất là: -3

# %%
#W3A17
# numbers = list(map(int, input("Nhập các số cách nhau bởi dấu cách: ").split()))

# if len(numbers) > 1 and numbers[0] != 0:
#     ratio = numbers[1] / numbers[0]
#     if all(numbers[i-1] != 0 and numbers[i] / numbers[i-1] == ratio for i in range(1, len(numbers))):
#         print("Cấp số nhân với công bội =", ratio)
#     else:
#         print("Không tạo thành cấp số nhân")
# else:
#     print("Không tạo thành cấp số nhân")


#C2
# Nhập các số từ bàn phím
numbers = [float(x) for x in input("Nhập các số cách nhau bởi dấu cách: ").split()]
count = 0
for _ in numbers:
    count += 1
if count < 2 or numbers[0] == 0:
    print("Không tạo thành cấp số nhân")
else:
    ratio = numbers[1] / numbers[0]
    is_geo = True
    for i in range(1, count):
        if numbers[i-1] == 0 or numbers[i] / numbers[i-1] != ratio:
            is_geo = False
            break
    if is_geo:
        print("Danh sách tạo thành cấp số nhân với công bội =", ratio)
    else:
        print("Danh sách KHÔNG tạo thành cấp số nhân")
# Out:
# Danh sách KHÔNG tạo thành cấp số nhân
